# %%
import pandas as pd

# %%
# !ls -a
# Out:
# .   .ipynb_checkpoints	data.json  scrapy.cfg
# ..  Untitled.ipynb	item.csv   vnexpress

# %%
items = pd.read_csv('./item.csv')

# %%
items
# Out:
#                                                    body           category  \
# 0     Mưa lũ sau bão Goni khiến 4 người ở huyện Bình...            Thời sự
# 1     Chủ đầu tư công khai lần một, cơ quan thẩm địn...            Thời sự
# 2     Ngân sách trung ương hỗ trợ tối đa 40 triệu đồ...            Thời sự
# 3     Quảng Bình,Nhà chức trách cấm người dân, phươn...            Thời sự
# 4     Trong 10 năm, hơn 2.600 trí thức trẻ tình nguy...            Thời sự
# ...                                                 ...                ...
# 1470  Quốc hội nghe báo cáo về chủ trương chuyển mục...            Thời sự
# 1471  Do ảnh hưởng Covid-19, TP HCM phấn đấu thu ngâ...            Thời sự
# 1472  Quốc hội bãi nhiệm đại biểu đối với ông Phạm P...  Thời sự,Chính trị
# 1473  500 cây sao đen 10 tuổi, cao hơn 4 m trên đườn...            Thời sự
# 1474                                                NaN            Thời sự
#
#       comment                               date  id_user  \
# ...
